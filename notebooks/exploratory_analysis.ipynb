# %% [markdown]
# # NetworkIQ: Exploratory Data Analysis
# This notebook analyzes the Indian Store Data to compute ABC classifications and synthetic profiles for the multi-agent system.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/indian_store_data.csv')
print(df.head())
