# %% [markdown]
# # NetworkIQ: Benchmarking Analysis
# This notebook provides deeper analysis of the AI multi-agent system vs classical OR tools.

# %%
import pandas as pd
import matplotlib.pyplot as plt

bench_data = pd.DataFrame({
    'Strategy': ['OR-Only', 'AI Agents (Ours)'],
    'Service Level': [0.92, 0.964],
    'Total Cost': [12.0, 10.2]
})
print(bench_data)
